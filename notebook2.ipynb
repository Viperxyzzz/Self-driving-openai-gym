# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy


# Create environment
env = gym.make("LunarLander-v2")

# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(100000))
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading

env = gym.make("LunarLander-v2", render_mode="human")

model = DQN.load("dqn_lunar", env=env)


#mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(150):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    #obs, rewards, dones, info = test_env.step(action)
    vec_env.render()

vec_env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -124     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4132     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 383      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.2     |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4527     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 738      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4717     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4888     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.5     |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5056     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -132     |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 5294     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 5333     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.8     |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 5441     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2811     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 5476     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.2     |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.669    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 5500     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.4     |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.643    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 5519     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3758     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.6     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 5569     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.1     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 5594     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -153     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5671     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 5704     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5438     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 5678     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 5689     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -149     |
# |    exploration_rate | 0.385    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 5665     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -154     |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 5666     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 6792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -156     |
# |    exploration_rate | 0.318    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 5683     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7182     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5716     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.245    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 5721     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.217    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5432     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5286     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.157    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5290     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8873     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.124    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 5318     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9217     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.0886   |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 5334     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.0521   |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 5354     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5359     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5362     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 5362     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 5334     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 5287     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 5286     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 5304     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 5324     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 5351     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 5374     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 5382     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 5398     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 5407     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5416     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5431     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15392    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.6     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5440     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 15753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5455     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 16134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5453     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 5466     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 5481     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 5496     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 5510     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 5520     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 5530     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 5542     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 5547     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 5504     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19746    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 5469     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 5485     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 5492     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 20917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 5503     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 21293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 5505     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 21672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 5488     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 21992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 5499     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 22370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 5497     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 22696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 5497     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 23034    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 5504     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 23399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 5509     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 23738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 5522     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 24143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 5533     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 24533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 5536     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 24900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 5549     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 25341    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 5555     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 25680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 5563     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 26030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 5545     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 26397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 5522     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 26751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5522     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 27091    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 5485     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 27461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 5483     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 27832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 5495     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 28224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 5477     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 28551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -205     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 5485     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 28898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 5490     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 29240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 5492     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 29611    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 5496     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 29910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -203     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 5504     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 30305    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5507     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 30643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -208     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5517     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 31077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -207     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5523     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 31387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5523     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 31722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5514     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 32051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5520     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 32462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5525     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 32898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 5506     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 33294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 5484     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 33688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 5496     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 34084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 5501     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 34431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 5506     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 34751    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 5512     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 35139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 5517     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 35435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 5523     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 35805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5528     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 36128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 5533     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 36506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 5531     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 36871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 5536     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 37223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 5540     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 37601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5545     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 37934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5548     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 38311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5550     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 38658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5554     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 39058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5560     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 39442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5564     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 39775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 5564     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 40053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 5568     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 40365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5570     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 40718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5574     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 41066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.2     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5574     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 41383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5581     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 41808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.6     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5588     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 42155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5610     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 43385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.7     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5612     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 43756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5619     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 44152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.9     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5624     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 44437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 5624     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 44769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 5630     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 45195    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 5638     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 45633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5619     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 46051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 5618     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 46431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 5624     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 46765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 5632     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 47208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 5626     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 47570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 5631     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 47916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 5637     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 48300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 5640     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 48663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 5648     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 49066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 5653     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 49431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 5659     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 49750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 5579     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 50098    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 5309     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 50588    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 146      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -213     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 5075     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 51038    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.21     |
# |    n_updates        | 259      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -236     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 4880     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 51472    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.55     |
# |    n_updates        | 367      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -265     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 4641     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 52044    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 510      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -281     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 4450     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 52588    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 646      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -289     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 4025     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 53913    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.13     |
# |    n_updates        | 978      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | -292     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 3242     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 57104    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46     |
# |    n_updates        | 1775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | -294     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 2872     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 59631    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.676    |
# |    n_updates        | 2407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | -291     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 2499     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 63631    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.82     |
# |    n_updates        | 3407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | -288     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 2146     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 67631    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.94     |
# |    n_updates        | 4407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 269      |
# |    ep_rew_mean      | -289     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 1898     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 71631    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.686    |
# |    n_updates        | 5407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | -277     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 1738     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74833    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.96     |
# |    n_updates        | 6208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 332      |
# |    ep_rew_mean      | -275     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 1608     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 78833    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.645    |
# |    n_updates        | 7208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 368      |
# |    ep_rew_mean      | -271     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 1513     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 82833    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.77     |
# |    n_updates        | 8208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 404      |
# |    ep_rew_mean      | -264     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 1429     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 86833    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.817    |
# |    n_updates        | 9208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | -262     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 1354     |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 90056    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 10013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | -257     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 1308     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 93225    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.563    |
# |    n_updates        | 10806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 490      |
# |    ep_rew_mean      | -253     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 1266     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 96534    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 11633    |
# ----------------------------------
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env = gym.make("LunarLander-v2", render_mode="human")

model = DQN.load("dqn_lunar", env=env)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(500):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    #obs, rewards, dones, info = test_env.step(action)
    vec_env.render()

vec_env.close()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
